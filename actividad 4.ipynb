# %%
# %pip install cufflinks
# Out:
# ...
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install nbformat
# Out:
# ...
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cufflinks as cf
from IPython.display import display,HTML
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Leo mi archivo.csv
covid = pd.read_csv("COVID19Mexico (1).csv")
#Filtro por filas
covid= covid.iloc[0:100000,: ]
covid
# Out:
# /var/folders/_k/y1w3sds95nb7b2qqw5w4hw_00000gn/T/ipykernel_3663/274709091.py:2: DtypeWarning:
#
# Columns (39) have mixed types. Specify dtype option on import or set low_memory=False.
#        Unnamed: 0 FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  \
# 0               0          27/08/2022      1a4a8d       1    12.0        23.0
# 1               1          27/08/2022      01e27d       2     9.0        25.0
# 2               2          27/08/2022      13cf10       2     9.0         9.0
# 3               3          27/08/2022      13c92b       2    12.0         9.0
# 4               4          27/08/2022      04af5f       2    12.0         9.0
# ...           ...                 ...         ...     ...     ...         ...
# 99995       99995          27/08/2022      47548a       2    12.0         9.0
# 99996       99996          27/08/2022      5c2773       2     NaN         9.0
# 99997       99997          27/08/2022      aceb1f       2     4.0         NaN
# ...

# %%
valores_nulos=covid.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0               0
# FECHA_ACTUALIZACION      0
# ID_REGISTRO              0
# ORIGEN                   0
# SECTOR                   1
# ENTIDAD_UM               1
# SEXO                     1
# ENTIDAD_NAC              0
# ENTIDAD_RES              0
# MUNICIPIO_RES            1
# TIPO_PACIENTE            0
# FECHA_INGRESO            0
# FECHA_SINTOMAS           0
# FECHA_DEF                0
# INTUBADO                 0
# NEUMONIA                 0
# EDAD                     3
# NACIONALIDAD             0
# EMBARAZO                 2
# HABLA_LENGUA_INDIG       0
# INDIGENA                 0
# DIABETES                 0
# EPOC                     0
# ASMA                     0
# INMUSUPR                 0
# HIPERTENSION             1
# OTRA_COM                 0
# CARDIOVASCULAR           0
# OBESIDAD                 0
# RENAL_CRONICA            0
# TABAQUISMO               1
# OTRO_CASO                1
# TOMA_MUESTRA_LAB         0
# RESULTADO_LAB            0
# ...

# %%
#Realizamos una copia del dataframe
covid=covid.copy()

# %%
#Sustituir valores nulos con mediana
covid["SECTOR"]=covid["SECTOR"].fillna(round(covid["SECTOR"].median(),1))
covid

# %%
#Sustituir valores nulos con mediana
covid["ENTIDAD_UM"]=covid["ENTIDAD_UM"].fillna(round(covid["ENTIDAD_UM"].median(),1))
covid

# %%
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
covid["SEXO"] =covid["SEXO"].fillna(method="ffill") 
covid

# %%
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
covid["MUNICIPIO_RES"] =covid["MUNICIPIO_RES"].fillna(method="ffill") 
covid

# %%
valores_nulos=covid.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0               0
# FECHA_ACTUALIZACION      0
# ID_REGISTRO              0
# ORIGEN                   0
# SECTOR                   0
# ENTIDAD_UM               0
# SEXO                     0
# ENTIDAD_NAC              0
# ENTIDAD_RES              0
# MUNICIPIO_RES            0
# TIPO_PACIENTE            0
# FECHA_INGRESO            0
# FECHA_SINTOMAS           0
# FECHA_DEF                0
# INTUBADO                 0
# NEUMONIA                 0
# EDAD                     3
# NACIONALIDAD             0
# EMBARAZO                 2
# HABLA_LENGUA_INDIG       0
# INDIGENA                 0
# DIABETES                 0
# EPOC                     0
# ASMA                     0
# INMUSUPR                 0
# HIPERTENSION             1
# OTRA_COM                 0
# CARDIOVASCULAR           0
# OBESIDAD                 0
# RENAL_CRONICA            0
# TABAQUISMO               1
# OTRO_CASO                1
# TOMA_MUESTRA_LAB         0
# RESULTADO_LAB            0
# ...

# %%
#Sustituir valores nulos con mediana
covid["EDAD"]=covid["EDAD"].fillna(round(covid["EDAD"].median(),1))
covid

# %%
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
covid["EMBARAZO"] =covid["EMBARAZO"].fillna(method="ffill") 
covid

# %%
covid["PAIS_NACIONALIDAD"] =covid["PAIS_NACIONALIDAD"].fillna(method="ffill") 
covid
# Out:
#        Unnamed: 0 FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  \
# 0               0          27/08/2022      1a4a8d       1    12.0        23.0
# 1               1          27/08/2022      01e27d       2     9.0        25.0
# 2               2          27/08/2022      13cf10       2     9.0         9.0
# 3               3          27/08/2022      13c92b       2    12.0         9.0
# 4               4          27/08/2022      04af5f       2    12.0         9.0
# ...           ...                 ...         ...     ...     ...         ...
# 99995       99995          27/08/2022      47548a       2    12.0         9.0
# 99996       99996          27/08/2022      5c2773       2     9.0         9.0
# 99997       99997          27/08/2022      aceb1f       2     4.0         9.0
# 99998       99998          27/08/2022      db2a23       2     4.0         9.0
# 99999       99999          27/08/2022      a88222       2     4.0         9.0
#
# ...

# %%
valores_nulos=covid.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0               0
# FECHA_ACTUALIZACION      0
# ID_REGISTRO              0
# ORIGEN                   0
# SECTOR                   0
# ENTIDAD_UM               0
# SEXO                     0
# ENTIDAD_NAC              0
# ENTIDAD_RES              0
# MUNICIPIO_RES            0
# TIPO_PACIENTE            0
# FECHA_INGRESO            0
# FECHA_SINTOMAS           0
# FECHA_DEF                0
# INTUBADO                 0
# NEUMONIA                 0
# EDAD                     0
# NACIONALIDAD             0
# EMBARAZO                 0
# HABLA_LENGUA_INDIG       0
# INDIGENA                 0
# DIABETES                 0
# EPOC                     0
# ASMA                     0
# INMUSUPR                 0
# HIPERTENSION             1
# OTRA_COM                 0
# CARDIOVASCULAR           0
# OBESIDAD                 0
# RENAL_CRONICA            0
# TABAQUISMO               1
# OTRO_CASO                1
# TOMA_MUESTRA_LAB         0
# RESULTADO_LAB            0
# ...

# %%
covid
# Out:
#        Unnamed: 0 FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  \
# 0               0          27/08/2022      1a4a8d       1    12.0        23.0
# 1               1          27/08/2022      01e27d       2     9.0        25.0
# 2               2          27/08/2022      13cf10       2     9.0         9.0
# 3               3          27/08/2022      13c92b       2    12.0         9.0
# 4               4          27/08/2022      04af5f       2    12.0         9.0
# ...           ...                 ...         ...     ...     ...         ...
# 99995       99995          27/08/2022      47548a       2    12.0         9.0
# 99996       99996          27/08/2022      5c2773       2     9.0         9.0
# 99997       99997          27/08/2022      aceb1f       2     4.0         9.0
# 99998       99998          27/08/2022      db2a23       2     4.0         9.0
# 99999       99999          27/08/2022      a88222       2     4.0         9.0
#
# ...

# %%
#outliners

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=covid["ORIGEN"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)

# %%
#Encontramos Ouliers
outliers_iqr= covid[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr

# %%
#Obtenemos datos limpios
data_clean_iqr= covid[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=covid["SECTOR"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)

# %%
#Encontramos Ouliers
outliers_iqr= covid[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr

# %%
#Obtenemos datos limpios
data_clean_iqr= covid[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=covid["ENTIDAD_UM"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)

# %%
#Encontramos Ouliers
outliers_iqr= covid[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr

# %%
#Obtenemos datos limpios
data_clean_iqr= covid[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr

# %%
y=covid["SEXO"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)

# %%
#Encontramos Ouliers
outliers_iqr= covid[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr

# %%
#Obtenemos datos limpios
data_clean_iqr= covid[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr

# %%
covid
# Out:
#        Unnamed: 0 FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  \
# 0               0          27/08/2022      1a4a8d       1    12.0        23.0
# 1               1          27/08/2022      01e27d       2     9.0        25.0
# 2               2          27/08/2022      13cf10       2     9.0         9.0
# 3               3          27/08/2022      13c92b       2    12.0         9.0
# 4               4          27/08/2022      04af5f       2    12.0         9.0
# ...           ...                 ...         ...     ...     ...         ...
# 99995       99995          27/08/2022      47548a       2    12.0         9.0
# 99996       99996          27/08/2022      5c2773       2     9.0         9.0
# 99997       99997          27/08/2022      aceb1f       2     4.0         9.0
# 99998       99998          27/08/2022      db2a23       2     4.0         9.0
# 99999       99999          27/08/2022      a88222       2     4.0         9.0
#
# ...

# %%
y=covid["ENTIDAD_NAC"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)

# %%
#Encontramos Ouliers
outliers_iqr= covid[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr

# %%
#Obtenemos datos limpios
data_clean_iqr= covid[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr

# %%
y=covid["ENTIDAD_RES"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)

# %%
#Encontramos Ouliers
outliers_iqr= covid[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr

# %%
#Obtenemos datos limpios
data_clean_iqr= covid[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr

# %%
y=covid["MUNICIPIO_RES"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)

# %%
#Encontramos Ouliers
outliers_iqr= covid[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr

# %%
#Obtenemos datos limpios
data_clean_iqr= covid[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr

# %%
y=covid["TIPO_PACIENTE"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 1.0
# Limite inferior permitido 1.0

# %%
outliers_iqr= covid[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr

# %%
data_clean_iqr= covid[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr

# %%
covid
# Out:
#        Unnamed: 0 FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  \
# 0               0          27/08/2022      1a4a8d       1    12.0        23.0
# 1               1          27/08/2022      01e27d       2     9.0        25.0
# 2               2          27/08/2022      13cf10       2     9.0         9.0
# 3               3          27/08/2022      13c92b       2    12.0         9.0
# 4               4          27/08/2022      04af5f       2    12.0         9.0
# ...           ...                 ...         ...     ...     ...         ...
# 99995       99995          27/08/2022      47548a       2    12.0         9.0
# 99996       99996          27/08/2022      5c2773       2     9.0         9.0
# 99997       99997          27/08/2022      aceb1f       2     4.0         9.0
# 99998       99998          27/08/2022      db2a23       2     4.0         9.0
# 99999       99999          27/08/2022      a88222       2     4.0         9.0
#
# ...

# %%
y=covid["OTRO_CASO"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)

# %%
outliers_iqr= covid[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr

# %%
data_clean_iqr= covid[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr

# %%
y=covid["TOMA_MUESTRA_LAB"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)

# %%
outliers_iqr= covid[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr

# %%
data_clean_iqr= covid[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr

# %%
y=covid["RESULTADO_LAB"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)

# %%
outliers_iqr= covid[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr

# %%
data_clean_iqr= covid[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr

# %%
y=covid["TOMA_MUESTRA_ANTIGENO"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)

# %%
outliers_iqr= covid[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr

# %%
data_clean_iqr= covid[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr

# %%
y=covid["RESULTADO_ANTIGENO"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)

# %%
outliers_iqr= covid[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr

# %%
data_clean_iqr= covid[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr

# %%
covid
# Out:
#        Unnamed: 0 FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  \
# 0               0          27/08/2022      1a4a8d       1    12.0        23.0
# 1               1          27/08/2022      01e27d       2     9.0        25.0
# 2               2          27/08/2022      13cf10       2     9.0         9.0
# 3               3          27/08/2022      13c92b       2    12.0         9.0
# 4               4          27/08/2022      04af5f       2    12.0         9.0
# ...           ...                 ...         ...     ...     ...         ...
# 99995       99995          27/08/2022      47548a       2    12.0         9.0
# 99996       99996          27/08/2022      5c2773       2     9.0         9.0
# 99997       99997          27/08/2022      aceb1f       2     4.0         9.0
# 99998       99998          27/08/2022      db2a23       2     4.0         9.0
# 99999       99999          27/08/2022      a88222       2     4.0         9.0
#
# ...

# %%
y=covid["CLASIFICACION_FINAL"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)

# %%
outliers_iqr= covid[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr

# %%
data_clean_iqr= covid[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr

# %%
y=covid["MIGRANTE"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)

# %%
outliers_iqr= covid[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr

# %%
data_clean_iqr= covid[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr

# %%
y=covid["PAIS_ORIGEN"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)

# %%
outliers_iqr= covid[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr

# %%
data_clean_iqr= covid[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr

# %%
y=covid["UCI"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)

# %%
outliers_iqr= covid[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr

# %%
data_clean_iqr= covid[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr
